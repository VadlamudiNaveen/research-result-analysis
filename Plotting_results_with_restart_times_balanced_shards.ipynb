# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 960.0 kB/s eta 0:00:08
#                                               0.1/7.6 MB 1.1 MB/s eta 0:00:07
#                                               0.2/7.6 MB 1.2 MB/s eta 0:00:07
#      -                                        0.3/7.6 MB 1.3 MB/s eta 0:00:06
#      -                                        0.3/7.6 MB 1.4 MB/s eta 0:00:06
#      --                                       0.4/7.6 MB 1.4 MB/s eta 0:00:06
#      --                                       0.5/7.6 MB 1.5 MB/s eta 0:00:05
#      ---                                      0.6/7.6 MB 1.5 MB/s eta 0:00:05
#      ---                                      0.7/7.6 MB 1.5 MB/s eta 0:00:05
#      ----                                     0.8/7.6 MB 1.6 MB/s eta 0:00:05
#      ----                                     0.9/7.6 MB 1.6 MB/s eta 0:00:05
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

batch_3_results = [
    [100.10203838348389, 97.71536779403687, 99.32897472381592, 101.76466798782349, 98.50465893745422, 86.48118829727173, 84.11763834953308, 81.80932021141052, 84.93890738487244, 85.24258160591125],
    [57.45343470573425, 61.624488830566406, 63.935893535614014, 62.96290469169617, 62.36403036117554, 83.68789744377136, 77.97255253791809, 78.36994457244873, 73.70262312889099, 80.30242538452148],
    [74.33411383628845, 87.91416954994202, 77.20108985900879, 78.93503260612488, 78.42176795005798, 66.6684901714325, 67.6273946762085, 67.24150037765503, 73.76529169082642, 67.2001588344574],
    [68.17635679244995,67.47209906578064, 72.42124629020691, 85.62823581695557, 80.46102380752563, 79.55011200904846, 79.24228239059448, 79.99523067474365, 74.94707345962524, 74.69343709945679]
]

for i,data in enumerate(batch_3_results):
    val = 222 + i
    data.sort()
    plt.bar(list(range(1,11)),data)
    plt.xlabel("Number of Runs")
    plt.ylabel("Execution Time (Seconds)")
    plt.show()
#plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25, wspace=0.35)

# %%
# Shard_Size = 6 
# Group 3 
# Balanced Shards 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

batch_3_results = [
    [100.10203838348389, 97.71536779403687, 99.32897472381592, 101.76466798782349, 98.50465893745422, 86.48118829727173, 84.11763834953308, 81.80932021141052, 84.93890738487244, 85.24258160591125],
    [57.45343470573425, 61.624488830566406, 63.935893535614014, 62.96290469169617, 62.36403036117554, 83.68789744377136, 77.97255253791809, 78.36994457244873, 73.70262312889099, 80.30242538452148],
    [74.33411383628845, 87.91416954994202, 77.20108985900879, 78.93503260612488, 78.42176795005798, 66.6684901714325, 67.6273946762085, 67.24150037765503, 73.76529169082642, 67.2001588344574],
    [68.17635679244995,67.47209906578064, 72.42124629020691, 85.62823581695557, 80.46102380752563, 79.55011200904846, 79.24228239059448, 79.99523067474365, 74.94707345962524, 74.69343709945679]
]
color = ["red", "blue", "violet", "orange"]
batches = ["n = 2", "n = 3", "n = 4", "n = 5"]


for i,data in enumerate(batch_3_results):
    #data.sort()
    linelabel = batches.pop(0)
    linecolor = color.pop(0)
    plt.plot(list(range(1,11)),data, color = linecolor, label = linelabel)
    plt.xlabel("Run Number")
    plt.ylabel("Execution Time (Seconds)")
    plt.legend()
    plt.title("Results for Shard Size = 6")

plt.show()

batches = ["n = 2", "n = 3", "n = 4", "n = 5"]
color = ["red", "blue", "violet", "green"]

for i,data in enumerate(shard_size_4_results):
    avg_runtime[i] = np.average(data)
    plt1.bar(list(range(2,6)), avg_runtime, color = color, label = batches)
    plt1.xlabel("Batch Size")
    plt1.ylabel("Avg Execution Time (Seconds)")
    plt1.legend(title = "Batch Size")
    plt1.title("Average Run time for Shard Size = 6")
    plt1.show()
plt1.savefig("average_run_time.png", dpi =400)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 34
#      31 color = ["red", "blue", "violet", "green"]
#      33 for i,data in enumerate(shard_size_4_results):
# ---> 34     avg_runtime[i] = np.average(data)
#      35     plt1.bar(list(range(2,6)), avg_runtime, color = color, label = batches)
#      36     plt1.xlabel("Batch Size")
#
# NameError: name 'avg_runtime' is not defined

# %%
# Shard Size = 8
# Group = 4
# Balanced Shards 

avg_runtime = []
batches = ["n = 2", "n = 3", "n = 4", "n = 5"]
color = ["red", "blue", "violet", "green", "orange"]
shard_size_4_results = [
    [91.45582938194275, 82.24576330184937, 87.23908877372742, 81.43806910514832, 82.47429251670837], 
    [69.35900616645813, 64.45734763145447, 64.31481003761292, 61.405547857284546, 64.4724338054657],  
    [54.046276330947876, 48.86175537109375, 99.94525599479675, 69.27745079994202 , 65.60489225387573],
    [65.62121868133545, 67.19351744651794, 66.5682578086853, 59.931758642196655, 58.525757789611816]
]

#for i,data in enumerate(shard_size_4_results):
    #data.sort()
    #linelabel = batches.pop(0)
    #linecolor = color.pop(0)
    #plt.plot(list(range(1,6)), data, color = linecolor, label = linelabel)
    #plt.xlabel("Run Number")
    #plt.ylabel("Execution Time (Seconds)")
    #plt.legend()
    #plt.title("Results for Shard Size = 8")

#plt.show()

batches = ["n = 2", "n = 3", "n = 4", "n = 5"]
color = ["red", "blue", "violet", "green",]

for i,data in enumerate(shard_size_4_results):
    avg_runtime[i] = np.average(data)
    plt1.bar(list(range(2,6)), avg_runtime, color = color, label = batches)
    plt1.xlabel("Batch Size")
    plt1.ylabel("Avg Execution Time (Seconds)")
    plt1.legend(title = "Batch Size")
plt1.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 31
#      28 color = ["red", "blue", "violet", "green",]
#      30 for i,data in enumerate(shard_size_4_results):
# ---> 31     avg_runtime[i] = np.average(data)
#      32     plt1.bar(list(range(2,6)), avg_runtime, color = color, label = batches)
#      33     plt1.xlabel("Batch Size")
#
# IndexError: list assignment index out of range

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt1
# Shard Size = 10
# Group = 4
# Balanced Shards 

batches = ["n = 2", "n = 3", "n = 4", "n = 5"]
color = ["red", "blue", "violet", "green"]
shard_size_4_results = [
    [98.33336782455444, 82.70761585235596, 80.01459407806396, 77.78621530532837, 77.70706248283386, 77.77276158332825, 77.60112857818604, 77.527667760849, 77.92270684242249, 77.95716595649719],
    [96.10682964324951, 81.5907814502716, 78.28601217269897, 78.11969637870789, 78.52886533737183, 75.05692386627197, 79.3219633102417, 370.876127243042, 74.8307785987854, 70.68973970413208, 196.22062230110168],
    [81.16554045677185, 61.802820682525635, 60.86877202987671, 60.417351722717285, 60.778175354003906, 60.76886820793152, 58.08405566215515, 60.388232707977295, 55.894853830337524, 56.52332592010498, 54.83551263809204]
   
]
avg_runtime = [0]*4
for i,data in enumerate(shard_size_4_results):
    #data.sort()
    linelabel = batches.pop(0)
    linecolor = color.pop(0)
    plt.plot(list(range(1,11)), data, color = linecolor, label = linelabel)
    plt.xlabel("Run Number")
    plt.ylabel("Execution Time (Seconds)")
    plt.legend(title = "Batch Size")
    plt.title("Results for Shard Size = 8")
plt.show()

batches = ["n = 2", "n = 3", "n = 4", "n = 5"]
color = ["red", "blue", "violet", "green",]

for i,data in enumerate(shard_size_4_results):
    avg_runtime[i] = np.average(data)
    plt1.bar(list(range(2,6)), avg_runtime, color = color, label = batches)
    plt1.xlabel("Batch Size")
    plt1.ylabel("Avg Execution Time (Seconds)")
    plt1.legend(title = "Batch Size")
    plt1.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 22
#      20 linelabel = batches.pop(0)
#      21 linecolor = color.pop(0)
# ---> 22 plt.plot(list(range(1,11)), data, color = linecolor, label = linelabel)
#      23 plt.xlabel("Run Number")
#      24 plt.ylabel("Execution Time (Seconds)")
#
# File ~\miniconda3\Lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# ...
